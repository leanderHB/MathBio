# %% [markdown]
# # Plots bifurc, fastest growing mode

# %%
a=  2.3 #????? a=2.3 in paper

b = 2.19
c = 0.62
β = b/(a*c)**0.5
# β = 1.89 # dit is gek...
print("β:",β)
κ1 = 1
def C(M):
    m_0 = M*(a/c)**0.5
    m_0 = M
    return (2*β**2*m_0**2 - 5*β*m_0**3 - 3*β*m_0 + 3*m_0**4 + 4*m_0**2 + 1)

def C(M):
    # m_0 = M*(a/c)**0.5
    m_0 = M
    return (m_0**2-β*m_0+1)*(3*m_0**2-2*β*m_0+1)


import numpy as np 
import matplotlib.pyplot as plt 

M_0 = np.linspace(0,1,1000000)
plt.plot(M_0,np.sqrt(-C(M_0)/κ1),c="black")
# plt.plot(M_0,-np.sqrt(C(M_0)/κ1),c="black")
K = np.sqrt(C(M_0))

M_nul = M_0[~np.isnan(K)]
th = 0.6
plt.plot(M_nul[M_nul<th],0*M_nul[M_nul<th],c="black",label="fastest growing mode")
plt.plot(M_nul[M_nul>th],0*M_nul[M_nul>th],c="black")
plt.xlabel("$m_0$")
plt.ylabel("$K_*$ [au]")
plt.yticks([0])

plt.xticks([0,0.5,1])
plt.gca().set_xticklabels(["$0$","$1/2$","$1$"])


print(β)
scale = 0.7
plt.gcf().set_size_inches(5*scale,4*scale)
plt.legend(loc="upper left")
plt.tight_layout()
plt.savefig("fastest_mode.pdf")
# Out:
# β: 1.8339367445933639
# 1.8339367445933639
# /tmp/ipykernel_5950/1670747260.py:24: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(M_0,np.sqrt(-C(M_0)/κ1),c="black")
# /tmp/ipykernel_5950/1670747260.py:26: RuntimeWarning: invalid value encountered in sqrt
#   K = np.sqrt(C(M_0))

# %%
import numpy as np 
import matplotlib.pyplot as plt 


β = np.linspace(1.7,2.5,1000)

m_1 = 0.5*(β-(β**2-4)**0.5)
m_2 = 0.5*(β+(β**2-4)**0.5)
m_3 = 1/3*(β-(β**2-3)**0.5)
m_4 = 1/3*(β+(β**2-3)**0.5)

# plt.plot(m_1,β)

m_12 = np.concatenate((np.flip(m_2),m_1))
β = np.concatenate((np.flip(β),β))
β_12 = β[~np.isnan(m_12)]
m_12 = m_12[~np.isnan(m_12)]



m_34 = np.concatenate((np.flip(m_4),m_3))
β_34 = β[~np.isnan(m_34)]
m_34 = m_34[~np.isnan(m_34)]

closest = 0
# for 
plt.gcf().set_size_inches(5*scale,4*scale)

plt.plot(m_12,β_12,c="black",linestyle="dashed",label="roots")
plt.plot(m_34,β_34,c="black",linestyle="dashed")
plt.ylim([1.7,2.1])
plt.xlim([0,1.2])

plt.fill_between(np.concatenate((m_12[m_12<=1],np.flip(m_34[m_34<=1]),[m_12[m_12<=1][0]])),np.concatenate((β_12[m_12<=1],np.flip(β_34[m_34<=1]),[β_12[m_12<=1][0]])),alpha=0.3)

plt.fill_between(np.concatenate((m_12[m_12>=1],np.flip(m_34[m_34>=1]),[m_12[m_12>=1][0]])),np.concatenate((β_12[m_12>=1],np.flip(β_34[m_34>=1]),[β_12[m_12>=1][0]])),alpha=0.3,color="C0",label="patterns")


plt.fill_between([-1,1,1,3,3,-1],[2,2,-1,-1,3,3],color="red",alpha=0.1,label="non-biological")
# plt.fill_between([1,1,2,2],[-1,2,2,-1],color="red",alpha=0.1)
plt.legend(loc="upper left")
plt.yticks([3**0.5,2])
plt.xticks([0,3**(-0.5),1])
plt.gca().set_xticklabels(["$0$","$1/\\sqrt{3}$","$1$"])
plt.gca().set_yticklabels(["$\\sqrt{3}$","$2$"])
plt.xlabel("$m_0$")
plt.ylabel("$\\beta$")
# plt.plot([3**(-0.5),3**(-0.5)],[-1,5])
plt.tight_layout()
plt.savefig("bif_beta_m0.pdf")
# Out:
# /tmp/ipykernel_179263/2257728670.py:7: RuntimeWarning: invalid value encountered in sqrt
#   m_1 = 0.5*(β-(β**2-4)**0.5)
# /tmp/ipykernel_179263/2257728670.py:8: RuntimeWarning: invalid value encountered in sqrt
#   m_2 = 0.5*(β+(β**2-4)**0.5)
# /tmp/ipykernel_179263/2257728670.py:9: RuntimeWarning: invalid value encountered in sqrt
#   m_3 = 1/3*(β-(β**2-3)**0.5)
# /tmp/ipykernel_179263/2257728670.py:10: RuntimeWarning: invalid value encountered in sqrt
#   m_4 = 1/3*(β+(β**2-3)**0.5)

# %%
import numpy as np 
import matplotlib.pyplot as plt 

plt.plot([-1,1],[0,0],c="black")
plt.plot([0,0],[0,0.8],c="black")
plt.axis("off")
x = np.linspace(-1,1,1000)
plt.plot(x,-0.3*np.exp(-x**2*2)+np.exp(-x**2*10),c="black")
plt.text(0,-0.1,"0",size=20,ha="center",va="center")
plt.text(0.9,0.1,"x",size=20,ha="center",va="center")

plt.text(0.1,0.3,"+",size=20,ha="center",va="center")
plt.text(-0.1,0.3,"+",size=20,ha="center",va="center")

plt.text(0.6,-0.05,"-",size=20,ha="center",va="center")
plt.text(-0.6,-0.05,"-",size=20,ha="center",va="center")

plt.text(0.7,0.5,"Excitatory",size=20,ha="center",va="center")
plt.text(-0.7,0.3,"Inhibitory",size=20,ha="center",va="center")

plt.plot([0.4,0.2],[0.43,0.2],c="black",linewidth=0.7)
plt.plot([-0.75,-0.5],[0.23,-0.02],c="black",linewidth=0.7)

plt.gcf().set_size_inches(5,2.5)
plt.savefig("kernel.pdf",transparent=True)

# %%
fig,axs = plt.subplots(1,3)
u = [0.6,0.4]
u = np.array(u)/np.linalg.norm(u)
angle = np.arctan2(u[0],u[1])
R = [[np.cos(angle),np.sin(angle)],[-np.sin(angle),np.cos(angle)]]
arrow = [[0,0,-0.1,0,0.1],[0,1,0.9,1,0.9]]

arrow_rot = np.dot(R,arrow)
arrow_rot = arrow_rot*np.linalg.norm(u)
for ax in axs:
    ax.text(-0.25,0,"$x$",va="center",ha="center")
    ax.text(1.15*u[0],1.15*u[1],"$\\vec u$",va="center",ha="center")
    # ax.set_title("hoi")
    ax.scatter([0],[0],c="black")
    # ax.plot([0,u[0]],[0,u[1]],c="black")
    ax.plot(arrow_rot[0],arrow_rot[1],c="black")
    ax.plot([u])
    ax.axis("equal")
    ax.set_xlim([-1,1])
    ax.set_ylim([-1,1])
    ax.axis("off")


phi = np.linspace(0,2*np.pi)
x=0.15*np.sin(phi)
y=0.15*np.cos(phi)
axs[0].plot(x,y,alpha=0.5,linestyle="dotted",c="C0")
axs[0].plot(x+u[0]/4,y+u[1]/4,alpha=1,c="C0")
axs[0].plot()

axs[1].plot([-3*u[0],0,3],[-3*u[1],0,-1],c="C0")
angle = np.arctan2(3,-1)
R = [[np.cos(angle),np.sin(angle)],[-np.sin(angle),np.cos(angle)]]
arrow = [[0,0,-0.1,0,0.1],[0,1,0.9,1,0.9]]
arrow_rot = np.dot(R,arrow)
axs[1].plot(arrow_rot[0],arrow_rot[1],c="C0")


axs[2].plot([1,0,3*u[0]],[-1,0,3*u[1]],c="C0")
angle = np.arctan2(-1,1)
R = [[np.cos(angle),np.sin(angle)],[-np.sin(angle),np.cos(angle)]]
arrow = [[0,0,-0.1,0,0.1],[0,1,0.9,1,0.9]]
arrow_rot = np.dot(R,arrow)
axs[2].plot(arrow_rot[0]+1.3,arrow_rot[1]-1.3,c="C0")


axs[0].text(-0.7,-0.7,"moving out")
axs[1].text(-0.7,-0.7,"disaligning")
axs[2].text(-0.7,-0.7,"aligning")

for ax in axs:
    # ax.axis("equal")
    ax.set_xlim([-1,1])
    ax.set_ylim([-1,1])
# fig.tight_layout()
fig.set_size_inches(6,2)
fig.savefig("change.pdf",transparent=True)

# %%
v = """-0.07087600830660998, 0.7904509272498345
-0.06639087842557406, 0.7769346336882987
-0.061105852769576335, 0.7635348598988454
-0.0559636656448218, 0.7510089844000084
-0.05082147852006724, 0.7383374591860687
-0.04567929139531268, 0.7257387588296804
-0.04053710427055818, 0.7136498324761518
-0.03539491714580362, 0.7012696066924176
-0.030109891489805862, 0.6886385397326731
-0.02396783464634905, 0.6751740327365072
-0.018539970459108157, 0.6619684585671908
-0.012255075084408151, 0.6482385454235045
-0.005827341178465006, 0.63373183379927
0.0006003927274781939, 0.6196329413773234
0.007028126633421394, 0.6055923088414177
0.013923332096160423, 0.5913504148810065
0.02052636783590206, 0.5769867047952366
0.02645416688249408, 0.5642860496382764
0.03320653381398997, 0.5509392393815876
0.039809569553731605, 0.537195202629164
0.046237303459674806, 0.5243197678140804
0.0548076153342657, 0.5082594592287499
0.06414313362623081, 0.49237670458183047
0.06937714552107022, 0.48053746345419224
0.0783759729893907, 0.466409441089225
0.08608925367652248, 0.45242706843936054
0.09380253436365432, 0.4386388954096331
0.10151581505078616, 0.4254333212403166
0.10922909573791795, 0.41222774707100013
0.11694237642504979, 0.39941057214195763
0.12465565711218157, 0.3869817964531892
0.13301171118990773, 0.37352653705798233
0.14201053865822816, 0.35962739281674794
0.15100936612654864, 0.34606116221003425
0.16000819359486906, 0.33274461682921097
0.16900702106318954, 0.31992744190016853
0.17800584853150997, 0.30727672378838633
0.18764744939042477, 0.29432430269531995
0.19793182363993383, 0.2811430034785206
0.20821619788944296, 0.26825300369192673
0.21914334552954634, 0.2549260547600246
0.2307132665602441, 0.24178521379742046
0.24228318759094175, 0.22896803886837802
0.2538531086216395, 0.216992395626596
0.5829530846059303, 0.054617973844163004
0.5970940991990055, 0.06526364392985529
0.6112351137920804, 0.0776571105967806
0.6240905816039668, 0.09011531047041821
0.6350177292440702, 0.10228515333233734
0.6453021034935793, 0.11510232826137978
0.6549437043524939, 0.12816918841631264
0.66329975843022, 0.14054247849932777
0.6710130391173519, 0.1529712541880961
0.6787263198044837, 0.16637102797754955
0.6857968271010213, 0.179188202906592
0.6922245610069644, 0.19165581851938795
0.6986522949129075, 0.20493907253675914
0.7050800288188508, 0.21880492541454144
0.7108649893341996, 0.2320590494888921
0.7160071764589542, 0.24443927527262632
0.7211493635837087, 0.25740209991677154
0.7262915507084633, 0.270801873706225
0.7314337378332179, 0.28478424635608945
0.7365759249579724, 0.2993492178663649
0.741718112082727, 0.3144967882370515
0.7468602992074815, 0.3303726071832518
0.7513597129416416, 0.3446462792633218
0.7552163532852076, 0.35746345419236425
0.7590729936287735, 0.3702806291214067
0.7629296339723395, 0.38368040291086014
0.7667862743159053, 0.3976627755607246
0.7712856880500656, 0.41145094859045206
0.7751423283936314, 0.42611301991079614
0.7789989687371974, 0.4412605902814827
0.7828556090807632, 0.45708785932264867
0.7867122494243293, 0.4731093279839517
0.7905688897678951, 0.48971339550566584
0.7944255301114609, 0.5070942615079279
0.7982821704550269, 0.5236012292195735
0.8021388107985927, 0.5422443927527261
0.8059954511421588, 0.5604020572355364
0.8097235368076057, 0.5776858234277299
0.8124231850481018, 0.5922507949380054
0.8149942786104791, 0.6053592692972534
0.8175653721728564, 0.6184677436565014
0.8201364657352337, 0.631721867730852
0.822707559297611, 0.6455585906656137
0.8252786528599882, 0.6595409633154783
0.8278497464223655, 0.6738146353955482
0.8304208399847428, 0.6886709063360292
0.8323491601565258, 0.7013909814550032
0.8354344724313785, 0.7165773917497171
0.8374913472812804, 0.7312977229561022
0.8400624408436577, 0.7451829957958982
0.8426335344060347, 0.7610588147420985
0.8457188466808876, 0.7783328709532853
0.8484184949213838, 0.7947038989308349"""

vx = [float(x.split(", ")[0]) for x in v.split("\n")]
vy = [float(x.split(", ")[1]) for x in v.split("\n")]

gx = [float(x.split(", ")[0]) for x in g.split("\n")]
gy = [float(x.split(", ")[1]) for x in g.split("\n")]

# %%
import matplotlib.pyplot as plt
import numpy as np
a = 2.3
b = 2.19
c = 0.62
vx = np.array(vx)

V = a*vx**2-b*vx+c
f = V*(V+2*a*vx**2-b*vx)

scale = 0.7
plt.gcf().set_size_inches(5*scale,4*scale)


plt.plot(vx,vy,label="paper $\\mathcal{V}(m)$")
plt.plot(vx,V,linestyle="dashed",label="V(M)")

plt.plot(gx,gy,label="paper $g(m)$")
plt.plot(vx,f,linestyle="dashed",label="f(M)")
plt.ylim([-0.1,0.8])
plt.legend(loc="upper right")
plt.xlabel('"rescaled" mussel density')
plt.tight_layout()
plt.savefig("comparison.pdf")

# %%
import matplotlib.pyplot as plt
import numpy as np
a = 2.3
b = 2.19
c = 0.62
beta = b/(a*c)**0.5
vx = np.array(vx)
m = np.linspace(0,1.5,1000)
V = m**2-beta*m+1
g = (m**2-beta*m+1)*(3*m**2-2*beta*m+1)

scale = 0.7
plt.gcf().set_size_inches(5*scale,4*scale)


plt.plot(vx,vy,label="paper $\\mathcal{V}(m)$")
plt.plot(m,V,linestyle="dashed",label="$\\mathcal{V}(m)$")

plt.plot(gx,gy,label="paper $g(m)$")
plt.plot(m,g,linestyle="dashed",label="g(m)")
plt.ylim([-0.1,0.8])
plt.legend(loc="upper right")
plt.xlabel('rescaled mussel density m')
plt.tight_layout()
plt.savefig("comparison2.pdf")

# %%
print(0.56/0.23)
print(88/37)
# Out:
# 2.4347826086956523
# 2.3783783783783785

# %% [markdown]
# $$m_0 = M\cdot\sqrt{a/c}$$
# so:
# $$M=m_0\sqrt{c/a}$$

# %%
(0.23/0.37)**2
# Out:
# 0.3864134404674945

# %% [markdown]
# so:
# $$
# c/a \approx 0.4
# $$
# While the paper gives:

# %%
a = 2.3
c = 0.62
print(c/a)
# Out:
# 0.26956521739130435

# %% [markdown]
# So something is going wrong in their scaling...

# %%
import numpy as np 
import matplotlib.pyplot as plt 

import scipy
k1 = 0.0005
D0 = 1
β = 1.83
dx = 0.15

def C(M):
    m_0 = M
    return (m_0**2-β*m_0+1)*(3*m_0**2-2*β*m_0+1)


def P(m):
    return (3 / 5) * m**5 - (5 * β / 4) * m**4 + ((2 * β**2 + 4) / 3) * m**3 - (3 * β / 2) * m**2 + m


def d2(m):
    m1 = np.roll(m, -1, axis=0)+np.roll(m, 1, axis=0) + \
        np.roll(m, -1, axis=1)+np.roll(m, 1, axis=1)-4*m
    return m1/dx**2

def dm(m):
    return D0*d2(P(m)-k1*d2(m))


m = 3**(-0.5)+(1/2-np.random.rand(100, 100))/1000 
# plt.imshow(m)
T = np.linspace(0, 100, 10000)
dt = T[1]-T[0]

blob_size = []
freqs = np.arange(len(m))-(len(m)-1)/2
cnt = 0

for i,t in enumerate(T):
    
    m += dm(m)*dt
    print(m.var())

    if i%(len(T)//100)==0:
        plt.imshow(1-m, cmap=plt.cm.hsv, vmin=0, vmax=1.2)
        file_name = "plaatjes/"+"0"*(3-len(str(cnt)))+str(cnt)+".png"
        plt.axis("off")
        # plt.colorbar()

        plt.gcf().set_size_inches(5,5)
        plt.tight_layout()

        plt.savefig(file_name)
        # plt.clf()
        cnt+=1
# plt.show()
plt.hist(m.reshape(m.size))
plt.show()

plt.imshow(m)
# Out:
# 6.33876511389013e-08
# 5.213495302543627e-08
# 4.493958716824749e-08
# 3.9922984169424755e-08
# 3.621546019531872e-08
# 3.336432354498459e-08
# 3.110903046859994e-08
# 2.9287176548921216e-08
# 2.7791175276624404e-08
# 2.6546392325926192e-08
# 2.5499193041372174e-08
# 2.4609956586356224e-08
# 2.384876226908852e-08
# 2.31926036752114e-08
# 2.2623522147918013e-08
# 2.2127317726016988e-08
# 2.169263612517882e-08
# 2.1310308194014136e-08
# 2.097286334437492e-08
# 2.0674165559405503e-08
# 2.0409137436348608e-08
# 2.017354851273378e-08
# 1.9963851216016475e-08
# 1.9777052544824177e-08
# 1.961061286180609e-08
# 1.9462365464139303e-08
# 1.9330452220964095e-08
# 1.9213271736244206e-08
# 1.9109437348660214e-08
# 1.9017742909804417e-08
# 1.8937134751557378e-08
# 1.8866688607067245e-08
# 1.8805590518193526e-08
# 1.8753120967705682e-08
# 1.870864163285614e-08
# 1.867158427978592e-08
# 1.86414414141142e-08
# 1.8617758378336988e-08
# 1.8600126646076794e-08
# 1.8588178110351242e-08
# ...

# %%
plt.imshow(m, cmap=plt.cm.jet, vmin=0, vmax=0.8)
file_name = "plaatjes/"+"0"*(3-len(str(cnt)))+str(cnt)+".png"
plt.axis("off")
plt.colorbar()

# %%
plt.hist(np.reshape(m,m.size) ,bins=100)
print((a/c)**0.5)
plt.title("histogram of m")
plt.xlabel("m")
plt.savefig("hist_m.pdf")
# Out:
# 1.9260522888423457

# %%
preferred_states = """1.73219348073717, 0.5751438783479171
1.7360549105694736, 0.5396102527466675
1.7356258628103287, 0.6137816487992758
1.7412892932310409, 0.6389933618501624
1.7441210084413967, 0.5129786291930996
1.7495270102066218, 0.6646004537843961
1.754418154660873, 0.4912923093306828
1.7595667277706113, 0.6890923128804955
1.7652301581913232, 0.47424655224436907
1.7703787313010613, 0.7116469356241458
1.7760421617217732, 0.460633020358176
1.7811907348315115, 0.731721126710566
1.7868541652522234, 0.4485192843577501
1.7920027383619617, 0.750151310768357
1.7976661687826736, 0.43804955538595336
1.8028147418924116, 0.7672547523118156
1.8084781723131238, 0.428646988871337
1.8136267454228618, 0.783435242540956
1.819290175843574, 0.4201385314424664
1.824438748953312, 0.7988946770557853
1.830102179374024, 0.4122646030421896
1.8352507524837622, 0.8137195825420209
1.8409141829044742, 0.4048809925276441
1.8460627560142122, 0.8279676434568076
1.8517261864349241, 0.3981607532702649
1.8568747595446624, 0.8417830709430077
1.8625381899653743, 0.39167125184146534
1.8676867630751126, 0.8551947072291937
1.8733501934958245, 0.3856720682983972
1.8784987666055626, 0.8684332901439449
1.8841621970262747, 0.3799613070410537
1.8893107701360128, 0.881268081858682
1.8949742005567247, 0.3745678102980067
1.900122773666463, 0.8936990823734048
1.905786204087175, 0.36934736692639447
1.9109347771969132, 0.9059858717452653
1.9165982076176251, 0.3644441880690794
1.9217467807273632, 0.9179265543742567
1.927410211148075, 0.3597140625831987
1.9325587842578134, 0.9298383947746757
1.9382222146785253, 0.3551569904687527
1.9433707877882633, 0.941519497346515
1.9490342182089755, 0.3508594984114587
1.9541827913187135, 0.9530275465469197
1.9598462217394257, 0.3466485330398821
1.9649947948491637, 0.9643048579187448
1.9706582252698757, 0.3426394632683126
1.975806798379614, 0.975524484833425
1.9814702288003259, 0.33871692018246036
1.9866188019100641, 0.9866748903995315
1.991509946364315, 0.3351741331061453
1.994856518885645, 0.9965137611718254"""

# %%
px = [float(x.split(", ")[0]) for x in preferred_states.split("\n")]
py = [float(x.split(", ")[1]) for x in preferred_states.split("\n")]
import numpy as np 
import matplotlib.pyplot as plt 


plt.scatter(py,px,marker="x",color="red",label="preffered states\n(paper)")

β = np.linspace(1.7,2.5,1000)

m_1 = 0.5*(β-(β**2-4)**0.5)
m_2 = 0.5*(β+(β**2-4)**0.5)
m_3 = 1/3*(β-(β**2-3)**0.5)
m_4 = 1/3*(β+(β**2-3)**0.5)

# plt.plot(m_1,β)

m_12 = np.concatenate((np.flip(m_2),m_1))
β = np.concatenate((np.flip(β),β))
β_12 = β[~np.isnan(m_12)]
m_12 = m_12[~np.isnan(m_12)]



m_34 = np.concatenate((np.flip(m_4),m_3))
β_34 = β[~np.isnan(m_34)]
m_34 = m_34[~np.isnan(m_34)]

closest = 0
# for 
plt.gcf().set_size_inches(5*scale,4*scale)

plt.plot(m_12,β_12,c="black",linestyle="dashed",label="roots")
plt.plot(m_34,β_34,c="black",linestyle="dashed")
plt.ylim([1.7,2.1])
plt.xlim([0,1.2])

plt.fill_between(np.concatenate((m_12[m_12<=1],np.flip(m_34[m_34<=1]),[m_12[m_12<=1][0]])),np.concatenate((β_12[m_12<=1],np.flip(β_34[m_34<=1]),[β_12[m_12<=1][0]])),alpha=0.3)

plt.fill_between(np.concatenate((m_12[m_12>=1],np.flip(m_34[m_34>=1]),[m_12[m_12>=1][0]])),np.concatenate((β_12[m_12>=1],np.flip(β_34[m_34>=1]),[β_12[m_12>=1][0]])),alpha=0.3,color="C0",label="patterns")


plt.fill_between([-1,1,1,3,3,-1],[2,2,-1,-1,3,3],color="red",alpha=0.1,label="non-biological")
# plt.fill_between([1,1,2,2],[-1,2,2,-1],color="red",alpha=0.1)
plt.legend(loc="upper left")
plt.yticks([3**0.5,2])
plt.xticks([0,3**(-0.5),1])
plt.gca().set_xticklabels(["$0$","$1/\\sqrt{3}$","$1$"])
plt.gca().set_yticklabels(["$\\sqrt{3}$","$2$"])
plt.xlabel("$m_0$")
plt.ylabel("$\\beta$")
# plt.plot([3**(-0.5),3**(-0.5)],[-1,5])
plt.tight_layout()
plt.savefig("bif_beta_m0_preffered_states.pdf")
# Out:
# /tmp/ipykernel_179263/613916759.py:11: RuntimeWarning: invalid value encountered in sqrt
#   m_1 = 0.5*(β-(β**2-4)**0.5)
# /tmp/ipykernel_179263/613916759.py:12: RuntimeWarning: invalid value encountered in sqrt
#   m_2 = 0.5*(β+(β**2-4)**0.5)
# /tmp/ipykernel_179263/613916759.py:13: RuntimeWarning: invalid value encountered in sqrt
#   m_3 = 1/3*(β-(β**2-3)**0.5)
# /tmp/ipykernel_179263/613916759.py:14: RuntimeWarning: invalid value encountered in sqrt
#   m_4 = 1/3*(β+(β**2-3)**0.5)

# %%
import os
# param_type = "SNLC"
os.system("ffmpeg -r 20 -i plaatjes/%3d.png -vcodec mpeg4 -vb 40M -y out_blobblob.mp4")
# Out:
# ffmpeg version 5.1.2-3ubuntu1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 12 (Ubuntu 12.2.0-14ubuntu2)
# ...

# %% [markdown]
# # commands to make the gifs

# %%
ffmpeg -r 20 -i %3d.png -i palette.png -lavfi paletteuse=alpha_threshold=128 -gifflags -offsetting -vb 40M -y out.gif
ffmpeg -i %3d.png -vf palettegen=reserve_transparent=1 -y palette.png
